# %% [markdown]
# <a href="https://colab.research.google.com/github/Carmodann1311/visualizaci-n-de-datos/blob/main/practica_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
segments(x0, y0, x1 = x0, y1 = y0, ...)
# Out:
# Error: '...' used in an incorrect context
# Traceback:

# %%
plot(c(-11, 3), c(-10, 10), type="n", xlab="", ylab="")
grid()

segments(-9, 9, -9, -9, lwd=4, col=3)
segments(-9, -9, -5, -9, lwd=4, col=3)
segments(-5, -9, -5, 9, lwd=4, col=3)

segments(-4, -9, -4, 9, lwd=4)
segments(-4, 9, 0, -9, lwd=4)
segments(0, -9, 0, 9, lwd=4)
# Out:
# plot without title

# %%
rect(xleft, ybottom, xright, ytop,
     density = NULL, angle = 45, ...)
# Out:
# Error: '...' used in an incorrect context
# Traceback:

# %%
plot(NA, xlim=c(10, 20), ylim=c(10, 30), las=1, xlab='', ylab='')
rect(10, 28, 12, 30)
rect(11, 25, 13, 27, col='red')
rect(12, 22, 14, 24, density=5)
rect(13, 19, 15, 21, density=5, angle=15)
rect(14, 16, 16, 18, col='pink', border='blue')
rect(15, 13, 17, 15, lty='dashed')
rect(16, 10, 18, 12, lwd=3)

text(14, 26, "col='red'")
text(15, 23, "density=5")
text(17, 20, "density=5, angle=15")
text(18.2, 17, "col='pink', border='blue'")
text(18.2, 14, "lty='dashed'")
text(18.8, 11, "lwd=3")
# Out:
# plot without title

# %%
## set up the plot region:
plot(c(100, 250), c(300, 450), type="n", xlab="", ylab="",
     main="2 x 11 rectangles; 'rect(100+i,300+i, 150+i,380+i)'")
i <- 4*(0:10)
## draw rectangles with bottom left (100, 300)+i
## and top right (150, 380)+i
rect(100+i, 300+i, 150+i, 380+i, col=rainbow(11, start=0.7, end=0.1))
rect(240-i, 320+i, 250-i, 410+i, col=heat.colors(11), lwd=i/5)
# Out:
# Plot with title “2 x 11 rectangles; 'rect(100+i,300+i, 150+i,380+i)'”

# %%
polygon(x, y, density = NULL, angle = 45,
        border, col, lty, ...)

# %%
plot(0:5, 0:5, type="n", xlab="", ylab="")
abline(v=0:5, h=0:5, col=gray(0.8), lty='dashed')

polygon(x=c(0, 1, 2), y=c(1, 5, 2),         # Para el triangulo
        col='blue', border='red', lwd=4)

polygon(x=c(3, 5, 5, 2), y=c(5, 4, 1, 1), # Para el cuadrilatero
        col='orange', border='darkgreen', lwd=4)
# Out:
# plot without title

# %%
abline(a = NULL, b = NULL, h = NULL, v = NULL, reg = NULL,
       coef = NULL, untf = FALSE, ...)

# %%
plot(x=c(-5, 5), y=c(-10, 10),    # Para crear el lienzo
     xlab="", ylab="", type='n')  # donde se ubicará la recta

abline(a=-5, b=3, lwd=3, col='blue')
# Out:
# plot without title

# %%
plot(x=c(-5, 5), y=c(-10, 10),    # Para crear el lienzo
     xlab="", ylab="", type='n')  # donde se ubicará la recta

abline(h=c(5, -3), v=2,
       col=c('darkgreen', 'red', 'orange'), lwd=5)
# Out:
# plot without title

# %%
rad     <- 7   # Valor del radio
xcenter <- -2  # Coordenada en x del centro
ycenter <- 1   # Coordenada en y del centro

plot(c(-10, 10), c(-10, 10), type="n", xlab="", ylab="", asp=1)
theta <- seq(0, 2 * pi, length = 200)
polygon(x=rad * cos(theta) + xcenter,
        y=rad * sin(theta) + ycenter,
        lwd=3, col='steelblue1', border='steelblue4')
grid()  # Para incluir una cuadrícula de guía
# Out:
# plot without title

# %%
arrows(x0, y0, x1=x0, y1=y0, length=0.25, angle=30, ...)

# %%
plot(NA, xlab='X', ylab='Y',      # Para crear un gráfico vacío
     xlim=c(0, 6), ylim=c(0, 5))
arrows(x0=2, y0=1, x1=4, y1=1, code=0)
arrows(x0=5, y0=1, x1=5, y1=4, code=1)
arrows(x0=2, y0=4, x1=4, y1=4, code=2)
arrows(x0=1, y0=1, x1=1, y1=4, code=3)
text(3, 0.8, 'code=0')
text(5.4, 2.5, 'code=1')
text(3, 4.2, 'code=2')
text(0.6, 2.5, 'code=3')
# Out:
# plot without title

# %%
plot(NA, xlab='X', ylab='Y',      # Para crear un gráfico vacío
     xlim=c(0, 6), ylim=c(0, 5))

arrows(x0=1, y0=4, x1=4, y1=4)
arrows(x0=1, y0=3, x1=4, y1=3, angle=45)
arrows(x0=1, y0=2, x1=4, y1=2, angle=60)
arrows(x0=1, y0=1, x1=4, y1=1, angle=90)
text(4.5, 3, 'angle=45')
text(4.5, 2, 'angle=60')
text(4.5, 1, 'angle=90')
# Out:
# plot without title

# %%
grid(nx = NULL, ny = nx, col = "lightgray", lty = "dotted",
     lwd = par("lwd"), equilogs = TRUE)
# Out:
# Error: object 'nx' not found
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "object 'nx' not found", base::quote(eval(expr, envir)))

# %%
par(mfrow=c(1, 2), mar=c(2, 2, 0, 0), cex=0.5)
plot(c(-10, 10), c(-10, 10), type="n", xlab="", ylab="")
grid()

plot(c(-10, 10), c(-10, 10), type="n", xlab="", ylab="")
grid(nx=3, ny=4, col="pink", lwd=2, lty="longdash")
# Out:
# plot without title

# %%
points(x, y, pch, col, cex)

# %%
par(mar=c(2, 2, 0, 0))
plot(c(0.5, 5.5), c(0.5, 5.5), xlab="", ylab="", type='n')
points(x=1:5, y=1:5,
       pch=c('@', '.', '$', '%', 'w'),
       col=1:5)
# Out:
# plot without title

# %%
curve(expr, from = NULL, to = NULL, n = 101, add = FALSE,
      type = "l", log = NULL, xlim = NULL, ...)

# %%
f1 <- function(x) x^2 - 10
f2 <- function(x) ifelse(x < 1, -x^2, 5*x)
f3 <- function(x) 15 - 4 * x

curve(expr=f1, from=-2, to=7, type="l",
      col="blue", lwd=4, ylab='f(x)', xlim=c(-5, 10))

curve(expr=f2, from=-2, to=4, type="p",
      col="green4", add=TRUE)

curve(expr=f3, from=-5, to=0, type="b",
      col='red', add=TRUE, n=5)

text(x=7, y=9, "f1(x) usando type='l'", col="blue")
text(x=-2, y=4, "f2(x) usando type='p'", col="green4")
text(x=-1, y=30, "f3(x) usando type='b' y n=5", col="red")
# Out:
# plot without title

# %%
dat <- data.frame(t=seq(0, 2*pi, by=0.1))
xhrt <- function(t) 16*sin(t)^3
yhrt <- function(t) 13*cos(t)-5*cos(2*t)-2*cos(3*t)-cos(4*t)
dat$y <- yhrt(dat$t)
dat$x <- xhrt(dat$t)
with(dat, plot(x,y, type="l", lwd=10))
with(dat, polygon(x, y, col="hotpink"))
# Out:
# plot without title

# %% [markdown]
# Ejercicios para tarea. Agarrar tres

# %% [markdown]
# ejercicio 1
# Crear un gráfico vacío de manera que el eje horizontal tome valores desde 0 a 30 y el eje vertical valores de 0 a 20, usar los pasos de la sección 7.1 para construir el gráfico solicitado.

# %%
plot(NA, xlim = c(0, 30), ylim = c(0, 20), xlab = "", ylab = "")
# Out:
# plot without title

# %% [markdown]
# ejercicio 2
# Para el gráfico vacío creado en el paso anterior, agregar una rejilla o cuadrícula que pase por los valores enteros, use los pasos de la sección 7.6 para incluir la rejilla en los valores solicitados. El gráfico resultante de los ejercicios 1 y 2 debe ser similar al presentando en la Figura 6.15.

# %%
plot(NA, xlim = c(0, 30), ylim = c(0, 20), xlab = "", ylab = "")
grid()
# Out:
# plot without title

# %% [markdown]
# ejercicio 3
# Incluir en el gráfico vacío y con rejillas anterior el dibujo mostrado en la Figura 6.16. Use las funciones vistas en este capítulo para replicar el dibujo del paisaje e incluya colores para mejorar la apariencia del paisaje.

# %%
plot(NA, xlim = c(0, 30), ylim = c(0, 20), xlab = "", ylab = "")
grid()
rect(5, 5, 15, 12, col = "lightblue", border = "black")
polygon(x = c(5, 10, 15), y = c(12, 18, 12), col = "brown", border = "black")
rect(8, 8, 10, 10, col = "white", border = "black")
rect(12, 8, 14, 10, col = "white", border = "black")
rect(10, 3, 12, 5, col = "brown", border = "black")
# Car Structure
rect(20, 5, 28, 8, col = "red", border = "black")
rect(21, 8, 23, 10, col = "lightgray", border = "black")
rect(25, 8, 27, 10, col = "lightgray", border = "black")
polygon(x = c(20, 24, 28), y = c(8, 11, 8), col = "red", border = "black")
# Out:
# plot without title

# %% [markdown]
# ejercicio 4
# Dibujar las siguientes dos líneas en un mismo gráfico, la primera de color azul y la segunda de color verde.

# %%
plot(NA, xlim = c(-10, 10), ylim = c(-10, 10), xlab = "x", ylab = "y", type = "n")
abline(a = -8/5, b = 2/5, col = "blue", lwd = 2)
abline(a = -4/3, b = -1/3, col = "green", lwd = 2)
grid()
# Out:
# plot without title

# %% [markdown]
# ejercicio 5
# Dibujar la siguiente figura dada en forma parametrica.

# %%
t <- seq(0, 2*pi, length.out = 100)

x <- cos(t)
y <- sin(t)

plot(x, y, type = "l",
     xlab = "x", ylab = "y",
     main = "Parametric Equation: x = cos(t), y = sin(t)")

grid()
# Out:
# Plot with title “Parametric Equation: x = cos(t), y = sin(t)”
