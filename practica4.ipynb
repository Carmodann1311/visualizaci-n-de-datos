# %% [markdown]
# <a href="https://colab.research.google.com/github/Carmodann1311/visualizaci-n-de-datos/blob/main/practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Colores
colors()
# 1- negro   2- rojo   3- verde    4- azul
# 5- cyan   6- magenta 7- amarillo 8- gris

head(colors(),20)
tail(colors(),20)
# Out:
#   [1] "white"                "aliceblue"            "antiquewhite"
#   [4] "antiquewhite1"        "antiquewhite2"        "antiquewhite3"
#   [7] "antiquewhite4"        "aquamarine"           "aquamarine1"
#  [10] "aquamarine2"          "aquamarine3"          "aquamarine4"
#  [13] "azure"                "azure1"               "azure2"
#  [16] "azure3"               "azure4"               "beige"
#  [19] "bisque"               "bisque1"              "bisque2"
#  [22] "bisque3"              "bisque4"              "black"
#  [25] "blanchedalmond"       "blue"                 "blue1"
#  [28] "blue2"                "blue3"                "blue4"
#  [31] "blueviolet"           "brown"                "brown1"
#  [34] "brown2"               "brown3"               "brown4"
#  [37] "burlywood"            "burlywood1"           "burlywood2"
#  [40] "burlywood3"           "burlywood4"           "cadetblue"
#  [43] "cadetblue1"           "cadetblue2"           "cadetblue3"
# ...

# %%
# Dispercion
x1 <- 1:10
y1 <- 1:10

plot(x1,y1,main="Titulo", xlab="x", ylab="y",
     col=3,pch=10,cex=2)   # pch : 0 a 25   cex - tamaño

datos <- c(3,6,8,9,2,4,7)
plot(datos,col=rainbow(3))

plot(x1,y1,main="Titulo", col.main="red", cex.main = 3,
     xlab="x", ylab="y",
     col=3,pch=10,cex=2)
# Out:
# Plot with title “Titulo”
# plot without title
# Plot with title “Titulo”

# %%
# Dispercion
x1 <- 1:25
y1 <- 1:25

plot(x1,y1,main="dann", xlab="x", ylab="y",
     col=7,pch=20,cex=6)   # pch : 0 a 25   cex - tamaño

datos <- c(3,6,8,9,2,4,7)
plot(datos,col=rainbow(5))

plot(x1,y1,main="daniel", col.main="green", cex.main = 5,
     xlab="x", ylab="y",
     col=6,pch=22,cex=4)
# Out:
# Plot with title “dann”
# plot without title
# Plot with title “daniel”

# %%
# Linea
linea <- 1:10
plot(linea,type="b",lwd=3,col="green",pch=3)
# type: l , p , b, o, h, s
# line width
# pch picture chart ( 0 a 25)
# Out:
# plot without title

# %%
# Linea
linea <- 1:10
plot(linea,type="l",lwd=3,col="green",pch=3)
# type: l , p , b, o, h, s
# line width
# pch picture chart ( 0 a 25)
# Out:
# plot without title

# %%
# Linea
linea <- 1:10
plot(linea,type="p",lwd=3,col="green",pch=3)
# type: l , p , b, o, h, s
# line width
# pch picture chart ( 0 a 25)
# Out:
# plot without title

# %%
# Linea
linea <- 1:10
plot(linea,type="o",lwd=3,col="green",pch=3)
# type: l , p , b, o, h, s
# line width
# pch picture chart ( 0 a 25)
# Out:
# plot without title

# %%
# Linea
linea <- 1:10
plot(linea,type="h",lwd=3,col="green",pch=3)
# type: l , p , b, o, h, s
# line width
# pch picture chart ( 0 a 25)
# Out:
# plot without title

# %%
# Linea
linea <- 1:10
plot(linea,type="s",lwd=3,col="green",pch=3)
# type: l , p , b, o, h, s
# line width
# pch picture chart ( 0 a 25)
# Out:
# plot without title

# %%
plot(linea,type="b",lwd=3,col="green",pch=3,lty=3)
# lty:  0- removes line
#       1- solid line
#       2- dashed line
#       3- dotted line
#       4- dot dashed line
#       5- long dashee line
#       6- two dashed line
# Out:
# plot without title

# %%
plot(linea,type="b",lwd=3,col="green",pch=3,lty=0)
# lty:  0- removes line
#       1- solid line
#       2- dashed line
#       3- dotted line
#       4- dot dashed line
#       5- long dashee line
#       6- two dashed line
# Out:
# plot without title

# %%
plot(linea,type="b",lwd=3,col="green",pch=3,lty=1)
# lty:  0- removes line
#       1- solid line
#       2- dashed line
#       3- dotted line
#       4- dot dashed line
#       5- long dashee line
#       6- two dashed line
# Out:
# plot without title

# %%
plot(linea,type="b",lwd=3,col="green",pch=3,lty=2)
# lty:  0- removes line
#       1- solid line
#       2- dashed line
#       3- dotted line
#       4- dot dashed line
#       5- long dashee line
#       6- two dashed line
# Out:
# plot without title

# %%
plot(linea,type="b",lwd=3,col="green",pch=3,lty=4)
# lty:  0- removes line
#       1- solid line
#       2- dashed line
#       3- dotted line
#       4- dot dashed line
#       5- long dashee line
#       6- two dashed line
# Out:
# plot without title

# %%
plot(linea,type="b",lwd=3,col="green",pch=3,lty=5)
# lty:  0- removes line
#       1- solid line
#       2- dashed line
#       3- dotted line
#       4- dot dashed line
#       5- long dashee line
#       6- two dashed line
# Out:
# plot without title

# %%
plot(linea,type="b",lwd=3,col="green",pch=3,lty=6)
# lty:  0- removes line
#       1- solid line
#       2- dashed line
#       3- dotted line
#       4- dot dashed line
#       5- long dashee line
#       6- two dashed line
# Out:
# plot without title

# %%
plot(datos, bty="n", axes=FALSE, xlab="", ylab="",col="violet",pch=8)
axis(1, col="red")  # Change x-axis label color
axis(2, col="blue",las=1)  # Change y-axis label color
# Out:
# plot without title

# %%
plot(datos, bty="n", axes=FALSE, xlab="", ylab="",col="blue")
box(col="dodgerblue")
axis(1, col="dodgerblue", col.ticks="green", col.axis="orange", cex.axis=1.5)
axis(2, col="dodgerblue", col.ticks="green", col.axis="orange", cex.axis=0.8,las=1)
mtext("index", side=1, line=3, col="red", cex=1.5)
mtext("value", side=2, line=3, col="purple", cex=0.8)
# Out:
# plot without title

# %%
plot(datos, bty="n", axes=FALSE, xlab="", ylab="",col="blue")
box(col="dodgerblue")
axis(1, col="dodgerblue", col.ticks="green", col.axis="orange", cex.axis=2)
axis(2, col="dodgerblue", col.ticks="green", col.axis="orange", cex.axis=1.5,las=2)
mtext("index", side=1, line=3, col="red", cex=2)
mtext("value", side=2, line=3, col="purple", cex=1.5)
# Out:
# plot without title

# %%
# Lineas en una grafica
linea1 <- 1:10
linea2 <- c(2,4,6,3,1,8,7,9,6,2)
plot(linea1,type="l",lwd=3,col="green")
lines(linea2,type="l", lwd=2,col="red")
# Out:
# plot without title

# %%
# Barras
barplot(datos,col="cyan")               # Vertical
barplot(datos,col="cyan", horiz = TRUE)  # Horizontal
# Out:
# plot without title
# plot without title

# %%
barplot(datos,col="cyan",width=c(1,1,2,2,3,2,2,1),las=1,density = 10)
# las; 0, 1
# Density
# Out:
# plot without title

# %%
# Sectores
colors <- 1:7
myLabels= c("Uno","dos","tres","cuatro","cinco","seis","siete")
pie(datos, col=colors, main="Grafica de sectores")
legend("left",myLabels,fill=colors)
       # bottomleft  bottom  left  top
# Out:
# Plot with title “Grafica de sectores”

# %%
# Sectores
colors = c("white","aliceblue","antiquewhite","antiquewhite1","antiquewhite2","antiquewhite3","antiquewhite4")
myLabels= c("Uno","dos","tres","cuatro","cinco","seis","siete")
pie(datos, col=colors, main="Grafica de sectores")
legend("left",myLabels,fill=colors)
       # bottomleft  bottom  left  top
# Out:
# Plot with title “Grafica de sectores”

# %%
pie(datos, col=rainbow(7), main="Grafica de sectores",clockwise = TRUE,
    anlge=90)
legend("right",myLabels,fill=rainbow(7))
# Out:
# Warning message in text.default(1.1 * P$x, 1.1 * P$y, labels[i], xpd = TRUE, adj = ifelse(P$x < :
# “"anlge" is not a graphical parameter”
# Warning message in text.default(1.1 * P$x, 1.1 * P$y, labels[i], xpd = TRUE, adj = ifelse(P$x < :
# “"anlge" is not a graphical parameter”
# Warning message in text.default(1.1 * P$x, 1.1 * P$y, labels[i], xpd = TRUE, adj = ifelse(P$x < :
# “"anlge" is not a graphical parameter”
# Warning message in text.default(1.1 * P$x, 1.1 * P$y, labels[i], xpd = TRUE, adj = ifelse(P$x < :
# “"anlge" is not a graphical parameter”
# Warning message in text.default(1.1 * P$x, 1.1 * P$y, labels[i], xpd = TRUE, adj = ifelse(P$x < :
# “"anlge" is not a graphical parameter”
# Warning message in text.default(1.1 * P$x, 1.1 * P$y, labels[i], xpd = TRUE, adj = ifelse(P$x < :
# “"anlge" is not a graphical parameter”
# Warning message in text.default(1.1 * P$x, 1.1 * P$y, labels[i], xpd = TRUE, adj = ifelse(P$x < :
# “"anlge" is not a graphical parameter”
# ...

# %%
categorias<- c("no","A veces","si")
valores <- c(12,25,4)
colores=c("red","yellow","green")
pie(x=valores,
    labels=categorias,
    clockwise = TRUE,
    anlge=90,
    col=colores)
# Out:
# Warning message in text.default(1.1 * P$x, 1.1 * P$y, labels[i], xpd = TRUE, adj = ifelse(P$x < :
# “"anlge" is not a graphical parameter”
# Warning message in text.default(1.1 * P$x, 1.1 * P$y, labels[i], xpd = TRUE, adj = ifelse(P$x < :
# “"anlge" is not a graphical parameter”
# Warning message in text.default(1.1 * P$x, 1.1 * P$y, labels[i], xpd = TRUE, adj = ifelse(P$x < :
# “"anlge" is not a graphical parameter”
# Warning message in title(main = main, ...):
# “"anlge" is not a graphical parameter”
# plot without title

# %%
# Caja Brazos

boxplot(datos,col="yellow1")
points(mean(datos),pch=8)
# Out:
# plot without title

# %%
boxplot(datos,col="darkseagreen1",
        xlab="Eje x",
        ylab="Eje Y",
        main="Box Plot Vertical")
points(mean(datos),pch=8)
# Out:
# Plot with title “Box Plot Vertical”

# %%
boxplot(datos,col="yellow1",
        xlab="Eje x",
        ylab="Eje Y",
        main="Box Plot Horizontal",
        horizontal=TRUE)
points(mean(datos),pch=8)
# Out:
# Plot with title “Box Plot Horizontal”

# %%
# Densidad
plot(density(datos),col="red")
# Out:
# Plot with title “density(x = datos)”

# %%
# Histograma
hist(datos)

hist(datos,breaks=8,col="Violet",density=30,
     main="Titulo",xlab="x",ylab="y",las=1)
# Out:
# Plot with title “Histogram of datos”
# Plot with title “Titulo”

# %%
# Histograma & Densidad
hist(datos,freq=F,xlab="Years",main="Histogram & density curve")
lines(density(datos),lwd=3,col="red")
# Out:
# Plot with title “Histogram & density curve”

# %%
#Curvas
curve(sin,-2*pi, 2*pi,xname="t",col = "blue")
curve(cos,-2*pi, 2*pi,xname="t",col = "red")
# Out:
# plot without title
# plot without title

# %%
# Agrupando graficas
par(mfrow = c(2, 1))
curve(sin,-2*pi, 2*pi,xname="t",col = "blue")
curve(cos,-2*pi, 2*pi,xname="t",col = "red")
# Out:
# plot without title

# %%
par(mfrow = c(1, 2))
curve(sin,-2*pi, 2*pi,xname="t",col = "blue")
curve(cos,-2*pi, 2*pi,xname="t",col = "red")
# Out:
# plot without title

# %%
par(mfrow = c(1, 1))
curve(sin,-2*pi, 2*pi,xname="t",col = "blue")
curve(cos,-2*pi, 2*pi,xname="t",col = "red",add =TRUE)
# Out:
# plot without title

# %%
par(mfrow = c(2, 2))
curve(x^3 - 3*x, -2, 2,col = "blue")
curve(x^2 - 2, add = TRUE, col = "red")
hist(datos,col="green",density=30)
plot(density(datos),col="gray")
boxplot(datos,col="cyan",horizontal=TRUE)
# Out:
# Plot with title “density(x = datos)”
